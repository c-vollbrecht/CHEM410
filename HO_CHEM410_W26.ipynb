# %% [markdown]
# # Modeling the Harmonic Oscillator

# %% [markdown]
# Reminder that you MUST save your file. It does not automatically save

# %% [markdown]
# ## Goals
# The goals of this notebook are to creat a calcualtor for you for the harmonic oscillator model. Additionally this will help you to furhter understand how vibrational energy levels show up in spectroscopy.
#
# In a couple weeks, we will be doing a lab where you examine both vibration and rotation transitions in energy. This notebook will be incredibly helpful for that

# %% [markdown]
# ## Import Packages

# %%
#Same packages as PIB Model
import numpy as np              #library the expands python support for large and multidimensional arrays.
import sympy as sp              #symbolic math library
import matplotlib.pyplot as plt #plotting and graphing library
import pandas as pd             #pandas data anlysis library
import io                       #Core python input/output library
from scipy.stats import linregress       #Linear regression function from SciPy(contains linear regression function)
from scipy.optimize import curve_fit     #Curve fitting function from SciPy(for least squares regression)
from matplotlib import pyplot as plt
sp.init_printing(use_latex=True) #Use sympy "pretty printing" throughout document where possible.

# %% [markdown]
# ## Define Constants

# %% [markdown]
# Here we want to define constants that will be used through out the code

# %%
#Constants
h = 6.626e-34 #J*s
c = 2.99e8 #m/s
hbar = 1.05457e-34 #J*s

# %% [markdown]
# ## Define Variables

# %% [markdown]
# Below we will define variables we may want to change through out our calculations.
#
#
# To give us an example to work with, lets think about the Cl2 molecule today.
#
#
# As you put in the mass, you may want to include your conversion in the calculation. Start with the mass from the periodic table

# %%
m1 =  #kg, mass of atom 1
m2 =  #kg, mass of atom 2
reducedmass = m1*m2/(m1+m2) #kg, fill in the formula for reduced mass based on m1 and m2
k =  #N/m

# %% [markdown]
# Questions: What is a typical k value for a single bond? (think power of 10) How does this change for a double and triple bond?

# %% [markdown]
# Answer:

# %% [markdown]
# ## Calculate Energy at Single Level

# %%
#What n value do you want to calculate energy for?
n= 0   #0,1,2,3, etc

# %%
 
E_n = 


print ('The energy at', n, 'is', E_n, 'J')

# %% [markdown]
# Question: What is the zero-point energy?

# %% [markdown]
# Answer:

# %% [markdown]
# ## Calculate where we would expect to see this vibrational energy on a spectrum

# %%
#Find the delta E

# %%
#Convert E to wavelength(nm), wavenumber(cm-1), and frequency (s-1)

# %% [markdown]
# Question: Is the energy above where you expect in terms of wavelength and region of the electromagnetic spectrum?

# %% [markdown]
# Answer:

# %% [markdown]
# ## Application questions

# %% [markdown]
# Question: What would happen if you had a triple bond? What value would change? How would that effect what you would see in IR spectroscopy?

# %% [markdown]
# Answer:

# %% [markdown]
# Question:What would happen if you had an isotope? When will it be easiest to detect slight differences in energy due to an isotope?

# %% [markdown]
# Answer:

# %% [markdown]
# Question: Before we plotted the different energy levels and their spacing of the particle in the box. Why don't we do that here?

# %% [markdown]
# Answer:
