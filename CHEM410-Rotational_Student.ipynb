# %% [markdown]
# # Roti-Vibrational Spectra

# %% [markdown]
# In this notebook we will be putting together calculations for both purely rotational and roti-vibrational transitions.
#
#
# Outline of the notebook
#
# * Purely rotational energy values
#
# * Rotational and Vibrational values
#
# * Calculations from IR Specta

# %% [markdown]
# ### Import Packages

# %%
#Imnport the same packages you have used for the previous modules

import numpy as np              #library the expands python support for large and multidimensional arrays.
import sympy as sp              #symbolic math library
import matplotlib.pyplot as plt #plotting and graphing library
import pandas as pd             #pandas data anlysis library
import io                       #Core python input/output library
from scipy.stats import linregress       #Linear regression function from SciPy(contains linear regression function)
from scipy.optimize import curve_fit     #Curve fitting function from SciPy(for least squares regression)
from matplotlib import pyplot as plt
sp.init_printing(use_latex=True) #Use sympy "pretty printing" throughout document where possible.

# %% [markdown]
# ### Constants

# %%
h =
hbar= 
c =  #m/s
Na =

# %%
#Calculate reduced mass
m1 =   # kg
m2 = #kg
reducedmass =  #kg

# %% [markdown]
# NIST has lots of reference information for chemists!
#
# Check out this page to get an estimate of bond lenght for HCl
#
# https://cccbdb.nist.gov/exp2x.asp?casno=7647010&charge=0

# %%
#Calculate Moment of Inertia
r = #m
I =

# %% [markdown]
# Question: Why do we set the length between atoms to a fixed length (r) even though the bond is vibrating?

# %% [markdown]
# Answer:

# %%
#Calculate Rotational Constant of the molecule
B =

# %% [markdown]
# ## Purely Rotational Calculations

# %% [markdown]
# ### Calculate single Energy Level Values

# %%
#Calculate the energy of a single energy level in 2-D
J = 
EJ_2D =

# %%
#Calculate the energy of a single energy level in 3-D
J=2
EJ_3D =

# %% [markdown]
# ### Calculate delta E values

# %%
#Calculate the change in energy and the frequency for a P-branch transition (J-1)
dE_P = 
frequency_P = 
wavelength_R_m =  #wavelength in meters
wavelength_R_nm =  #wavelength in nanometers
wavenumber_R =  #wavenumber in cm-1

# %%
#Calculate the change in energy and the frequency for an R-branch transition (J +1)
dE_R = 
frequency_R =  #Hz
wavelength_R_m =  #wavelength in meters
wavelength_R_nm =  #wavelength in nanometers
wavenumber_R =  #wavenumber in cm-1

# %%
#Calculate the change in wavenumber between two rotational absorption lines

# %% [markdown]
# ## Create Plots
